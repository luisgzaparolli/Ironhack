# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import metrics
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# %%
diamonds_multi = pd.read_csv('./dataset/diamonds.csv')

# %%
diamonds_multi[['x','y','z']] = diamonds_multi[['x','y','z']].replace(0,np.NaN)
diamonds_multi.isnull().sum()
diamonds_multi.dropna(inplace=True)

# %%
diamonds_clean = pd.get_dummies(diamonds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8878db40e2bf> in <module>
# ----> 1 diamonds_clean = pd.get_dummies(diamonds)
#
# NameError: name 'diamonds' is not defined

# %%
X = diamonds_clean.select_dtypes(exclude = 'int64')
y = diamonds['price']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e35e48a6d008> in <module>
# ----> 1 X = diamonds_clean.select_dtypes(exclude = 'int64')
#       2 y = diamonds['price']
#
# NameError: name 'diamonds_clean' is not defined

# %%
diamonds_multi = diamonds
diamonds_multi.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
diamonds_multi[['carat', 'depth', 'table', 'price', 'x', 'y', 'z']] = diamonds_multi.select_dtypes(exclude = 'object').apply(lambda x: np.log10(x))

# %%
['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']
# Out:
# ['carat',
#  'depth',
#  'table',
#  'x',
#  'y',
#  'z',
#  'cut_Fair',
#  'cut_Good',
#  'cut_Ideal',
#  'cut_Premium',
#  'cut_Very Good',
#  'color_D',
#  'color_E',
#  'color_F',
#  'color_G',
#  'color_H',
#  'color_I',
#  'color_J']

# %%
diamonds_SI1 = diamonds_multi[(diamonds_multi['clarity'] == 'SI1')]
diamonds_SI1 = pd.get_dummies(diamonds_SI1)
diamonds_SI1.drop(labels = 'clarity_SI1',axis =1, inplace = True)

X_SI1 = diamonds_SI1[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']]
y_SI1 = diamonds_SI1['price']
train_x_SI1, test_x_SI1, train_y_SI1, test_y_SI1 = train_test_split(X_SI1, y_SI1,random_state = 42,test_size=0.2)
    
model_SI1 = LinearRegression()
model_SI1.fit(train_x_SI1, train_y_SI1)
y_pred_SI1 = model_SI1.predict(test_x_SI1)
    
r2_SI1 = r2_score(test_y_SI1, y_pred_SI1)
rsme_SI1 = math.sqrt(mean_squared_error(test_y_SI1,y_pred_SI1))
print(r2_SI1, rsme_SI1)
# Out:
# 0.9863594779356308 0.04995602258661622

# %%
['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']
# Out:
# ['carat',
#  'depth',
#  'table',
#  'x',
#  'y',
#  'z',
#  'cut_Fair',
#  'cut_Good',
#  'cut_Ideal',
#  'cut_Premium',
#  'cut_Very Good',
#  'color_D',
#  'color_E',
#  'color_F',
#  'color_G',
#  'color_H',
#  'color_I',
#  'color_J']

# %%
diamonds_VS1 = diamonds_multi[(diamonds_multi['clarity'] == 'VS1')]
diamonds_VS1 = pd.get_dummies(diamonds_VS1)
diamonds_VS1.drop(labels = 'clarity_VS1',axis =1, inplace = True)

X_VS1 = diamonds_VS1[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']]
y_VS1 = diamonds_VS1['price']
train_x_VS1, test_x_VS1, train_y_VS1, test_y_VS1 = train_test_split(X_VS1, y_VS1,random_state = 42,test_size=0.2)
    
model_VS1 = LinearRegression()
model_VS1.fit(train_x_VS1, train_y_VS1)
y_pred_VS1 = model_VS1.predict(test_x_VS1)
    
r2_VS1 = r2_score(test_y_VS1, y_pred_VS1)
rsme_VS1 = math.sqrt(mean_squared_error(test_y_VS1,y_pred_VS1))
print(r2_VS1, rsme_VS1)
# Out:
# 0.9871172416228742 0.05038521117458724

# %%
df = pd.DataFrame({'Actual': 10**test_y_VS1, 'Predicted': 10**y_pred_VS1})
print(df.head(10))
# Out:
#        Actual    Predicted
# 11620  5358.0  5482.942253
# 40613  1624.0  1585.606117
# 16006  7129.0  6363.718166
# 22701   640.0   623.973313
# 8091   4499.0  4077.101867
# 37730   504.0   593.522927
# 13221  5904.0  5002.864611
# 47185  2446.0  2764.715139
# 32289   473.0   455.712988
# 42473  1813.0  1818.719089

# %%
diamonds_VS2 = diamonds_multi[(diamonds_multi['clarity'] == 'VS2')]
diamonds_VS2 = pd.get_dummies(diamonds_VS2)
diamonds_VS2.drop(labels = 'clarity_VS2',axis =1, inplace = True)

X_VS2 = diamonds_VS2[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']]
y_VS2 = diamonds_VS2['price']
train_x_VS2, test_x_VS2, train_y_VS2, test_y_VS2 = train_test_split(X_VS2, y_VS2,random_state = 42,test_size=0.2)
    
model_VS2 = LinearRegression()
model_VS2.fit(train_x_VS2, train_y_VS2)
y_pred_VS2 = model_VS2.predict(test_x_VS2)
    
r2_VS2 = r2_score(test_y_VS2, y_pred_VS2)
rsme_VS2 = math.sqrt(mean_squared_error(test_y_VS2,y_pred_VS2))
print(r2_VS2, rsme_VS2)
# Out:
# 0.9841545659273176 0.05587503188322188

# %%
diamonds_SI2 = diamonds_multi[(diamonds_multi['clarity'] == 'SI2')]
diamonds_SI2 = pd.get_dummies(diamonds_SI2)
diamonds_SI2.drop(labels = 'clarity_SI2',axis =1, inplace = True)

X_SI2 = diamonds_SI2[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']]
y_SI2 = diamonds_SI2['price']
train_x_SI2, test_x_SI2, train_y_SI2, test_y_SI2 = train_test_split(X_SI2, y_SI2,random_state = 42,test_size=0.2)
    
model_SI2 = LinearRegression()
model_SI2.fit(train_x_SI2, train_y_SI2)
y_pred_SI2 = model_SI2.predict(test_x_SI2)
    
r2_SI2 = r2_score(test_y_SI2, y_pred_SI2)
rsme_SI2 = math.sqrt(mean_squared_error(test_y_SI2,y_pred_SI2))
print(r2_SI2, rsme_SI2)
# Out:
# 0.9730851621261367 0.06631477059846062

# %%
diamonds_VVS2 = diamonds_multi[(diamonds_multi['clarity'] == 'VVS2')]
diamonds_VVS2 = pd.get_dummies(diamonds_VVS2)
diamonds_VVS2.drop(labels = 'clarity_VVS2',axis =1, inplace = True)

X_VVS2 = diamonds_VVS2[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']]
y_VVS2 = diamonds_VVS2['price']
train_x_VVS2, test_x_VVS2, train_y_VVS2, test_y_VVS2 = train_test_split(X_VVS2, y_VVS2,random_state = 42,test_size=0.2)
    
model_VVS2 = LinearRegression()
model_VVS2.fit(train_x_VVS2, train_y_VVS2)
y_pred_VVS2 = model_VVS2.predict(test_x_VVS2)
    
r2_VVS2 = r2_score(test_y_VVS2, y_pred_VVS2)
rsme_VVS2 = math.sqrt(mean_squared_error(test_y_VVS2,y_pred_VVS2))
print(r2_VVS2, rsme_VVS2)
# Out:
# 0.9781630765495218 0.06566852278754713

# %%
diamonds_VVS1 = diamonds_multi[(diamonds_multi['clarity'] == 'VVS1')]
diamonds_VVS1 = pd.get_dummies(diamonds_VVS1)
diamonds_VVS1.drop(labels = 'clarity_VVS1',axis =1, inplace = True)

X_VVS1 = diamonds_VVS1[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']]
y_VVS1 = diamonds_VVS1['price']
train_x_VVS1, test_x_VVS1, train_y_VVS1, test_y_VVS1 = train_test_split(X_VVS1, y_VVS1,random_state = 42,test_size=0.2)
    
model_VVS1 = LinearRegression()
model_VVS1.fit(train_x_VVS1, train_y_VVS1)
y_pred_VVS1 = model_VVS1.predict(test_x_VVS1)
    
r2_VVS1 = r2_score(test_y_VVS1, y_pred_VVS1)
rsme_VVS1 = math.sqrt(mean_squared_error(test_y_VVS1,y_pred_VVS1))
print(r2_VVS1, rsme_VVS1)
# Out:
# 0.9804436186371214 0.055454981374708334

# %%
diamonds_I1 = diamonds_multi[(diamonds_multi['clarity'] == 'I1')]
diamonds_I1 = pd.get_dummies(diamonds_I1)
diamonds_I1.drop(labels = 'clarity_I1',axis =1, inplace = True)

X_I1 = diamonds_I1[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']]
y_I1 = diamonds_I1['price']
train_x_I1, test_x_I1, train_y_I1, test_y_I1 = train_test_split(X_I1, y_I1,random_state = 42,test_size=0.2)
    
model_I1 = LinearRegression()
model_I1.fit(train_x_I1, train_y_I1)
y_pred_I1 = model_I1.predict(test_x_I1)
    
r2_I1 = r2_score(test_y_I1, y_pred_I1)
rsme_I1 = math.sqrt(mean_squared_error(test_y_I1,y_pred_I1))
print(r2_I1, rsme_I1)
# Out:
# 0.9437540104277686 0.06944163632193713

# %%
diamonds_IF = diamonds_multi[(diamonds_multi['clarity'] == 'IF')]
diamonds_IF = pd.get_dummies(diamonds_IF)
diamonds_IF.drop(labels = 'clarity_IF',axis =1, inplace = True)

X_IF = diamonds_IF[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Fair',
       'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
       'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J']]
y_IF = diamonds_IF['price']
train_x_IF, test_x_IF, train_y_IF, test_y_IF = train_test_split(X_IF, y_IF,random_state = 42,test_size=0.2)
    
model_IF = LinearRegression()
model_IF.fit(train_x_IF, train_y_IF)
y_pred_IF = model_IF.predict(test_x_IF)
    
r2_IF = r2_score(test_y_IF, y_pred_IF)
rsme_IF = math.sqrt(mean_squared_error(test_y_IF,y_pred_IF))
print(r2_IF, rsme_IF)
# Out:
# 0.9853453374639943 0.049441994905266844

# %%
rick_diamonds = pd.read_csv('./dataset/rick_diamonds.csv')

# %%
rick_diamonds['x'] = rick_diamonds['x'].apply(lambda x: 0.1 if x==0 else x)
rick_diamonds['y'] = rick_diamonds['y'].apply(lambda x: 0.1 if x==0 else x)
rick_diamonds['z'] = rick_diamonds['z'].apply(lambda x: 0.1 if x==0 else x)

# %%
rick_diamonds[['carat', 'depth', 'table', 'x', 'y', 'z']] = rick_diamonds.select_dtypes(exclude = 'object').apply(lambda x: np.log10(x))

# %%
dummy_cut = pd.get_dummies(rick_diamonds[['cut', 'color']])
rick_diamonds = pd.concat([rick_diamonds, dummy_cut], axis=1)
rick_diamonds= rick_diamonds.drop(['cut', 'color'],axis=1)
rick_diamonds.head()
# Out:
#       carat clarity     depth     table         x         y         z  \
# 0 -0.040959     SI2  1.802089  1.755875  0.785330  0.790988  0.589950
# 1 -0.420216     VS2  1.780317  1.785330  0.670246  0.673021  0.451786
# 2 -0.283997     VS2  1.790988  1.748188  0.715167  0.712650  0.505150
# 3  0.041393     VS1  1.787460  1.748188  0.822822  0.825426  0.611723
# 4  0.357935     SI2  1.789581  1.755875  0.926342  0.922725  0.714330
#
#    cut_Fair  cut_Good  cut_Ideal  cut_Premium  cut_Very Good  color_D  \
# 0         0         0          0            0              1        0
# 1         0         1          0            0              0        0
# 2         0         0          1            0              0        0
# 3         0         0          1            0              0        0
# 4         0         0          1            0              0        0
#
#    color_E  color_F  color_G  color_H  color_I  color_J
# 0        0        0        0        1        0        0
# ...

# %%
y_pred = rick_diamonds[(rick_diamonds['clarity'] =='SI1')].select_dtypes(exclude = 'object')
np.exp(model_SI1.predict(y_pred))
# Out:
# array([30.13724309, 23.40224672, 13.19172638, ..., 28.92615184,
#        50.12654867, 39.34477885])

# %%
rick_SI1 = rick_diamonds[(rick_diamonds['clarity'] =='SI1')].select_dtypes(exclude = 'object')
y_SI1 = model_SI1.predict(rick_SI1)
y_pred_SI1 = 10**y_SI1
rick_diamonds_SI1 = rick_diamonds[(rick_diamonds['clarity'] =='SI1')]
rick_diamonds_SI1['price_predicted'] = y_pred_SI1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
rick_VS1 = rick_diamonds[(rick_diamonds['clarity'] =='VS1')].select_dtypes(exclude = 'object')
rick_VS1 = model_VS1.predict(rick_VS1)
rick_VS1 = 10**rick_VS1
rick_diamonds_VS1 = rick_diamonds[(rick_diamonds['clarity'] =='VS1')]
rick_diamonds_VS1['price_predicted'] = rick_VS1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
rick_VS2 = rick_diamonds[(rick_diamonds['clarity'] =='VS2')].select_dtypes(exclude = 'object')
rick_VS2 = model_VS2.predict(rick_VS2)
rick_VS2 = 10**rick_VS2
rick_diamonds_VS2 = rick_diamonds[(rick_diamonds['clarity'] =='VS2')]
rick_diamonds_VS2['price_predicted'] = rick_VS2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
rick_SI2 = rick_diamonds[(rick_diamonds['clarity'] =='SI2')].select_dtypes(exclude = 'object')
y_pred_SI2 = model_SI2.predict(rick_SI2)
y_pred_SI2 = 10**y_pred_SI2
rick_diamonds_SI2 = rick_diamonds[(rick_diamonds['clarity'] =='SI2')]
rick_diamonds_SI2['price_predicted'] = y_pred_SI2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
rick_SI2 = rick_diamonds[(rick_diamonds['clarity'] =='SI2')].select_dtypes(exclude = 'object')
y_pred_SI2 = model_SI2.predict(rick_SI2)

# %%
rick_diamonds[(rick_diamonds['clarity'] =='SI2')].select_dtypes(exclude = 'object').describe()
# Out:
#             carat       depth       table           x           y           z  \
# count  887.000000  887.000000  887.000000  887.000000  887.000000  887.000000
# mean    -0.023758    1.790549    1.762847    0.797116    0.796707    0.587888
# std      0.214791    0.011998    0.017181    0.093699    0.093073    0.088948
# min     -0.638272    1.726727    1.724276   -1.000000   -1.000000   -1.000000
# 25%     -0.142668    1.783904    1.748188    0.761928    0.761176    0.551450
# 50%      0.004321    1.791691    1.763428    0.806858    0.806180    0.599883
# 75%      0.093422    1.797268    1.770852    0.839164    0.839478    0.628389
# max      0.424882    1.842609    1.838849    0.947924    0.945961    0.746634
#
#          cut_Fair    cut_Good   cut_Ideal  cut_Premium  cut_Very Good  \
# count  887.000000  887.000000  887.000000   887.000000     887.000000
# mean     0.050733    0.114994    0.277339     0.323563       0.233371
# ...

# %%
rick_VVS2 = rick_diamonds[(rick_diamonds['clarity'] =='VVS2')].select_dtypes(exclude = 'object')
rick_VVS2 = model_VVS2.predict(rick_VVS2)
rick_VVS2 = 10**rick_VVS2
rick_diamonds_VVS2 = rick_diamonds[(rick_diamonds['clarity'] =='VVS2')]
rick_diamonds_VVS2['price_predicted'] = rick_VVS2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
rick_VVS1 = rick_diamonds[(rick_diamonds['clarity'] =='VVS1')].select_dtypes(exclude = 'object')
rick_VVS1 = model_VVS1.predict(rick_VVS1)
rick_VVS1 = 10**rick_VVS1
rick_diamonds_VVS1 = rick_diamonds[(rick_diamonds['clarity'] =='VVS1')]
rick_diamonds_VVS1['price_predicted'] = rick_VVS1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
rick_I1 = rick_diamonds[(rick_diamonds['clarity'] =='I1')].select_dtypes(exclude = 'object')
rick_I1 = model_I1.predict(rick_I1)
rick_I1 = 10**rick_I1
rick_diamonds_I1 = rick_diamonds[(rick_diamonds['clarity'] =='I1')]
rick_diamonds_I1['price_predicted'] = rick_I1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
rick_IF = rick_diamonds[(rick_diamonds['clarity'] =='IF')].select_dtypes(exclude = 'object')
rick_IF = model_IF.predict(rick_IF)
rick_IF = 10**rick_IF
rick_diamonds_IF = rick_diamonds[(rick_diamonds['clarity'] =='IF')]
rick_diamonds_IF['price_predicted'] = rick_IF
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
result = pd.concat([rick_diamonds_VS1, rick_diamonds_VS2, rick_diamonds_SI1, rick_diamonds_VVS2, rick_diamonds_VVS1, rick_diamonds_I1, rick_diamonds_IF, rick_diamonds_SI2])

# %%
result= result.sort_index()

# %%
result
# Out:
#          carat clarity     depth     table         x         y         z  \
# 0    -0.040959     SI2  1.802089  1.755875  0.785330  0.790988  0.589950
# 1    -0.420216     VS2  1.780317  1.785330  0.670246  0.673021  0.451786
# 2    -0.283997     VS2  1.790988  1.748188  0.715167  0.712650  0.505150
# 3     0.041393     VS1  1.787460  1.748188  0.822822  0.825426  0.611723
# 4     0.357935     SI2  1.789581  1.755875  0.926342  0.922725  0.714330
# ...        ...     ...       ...       ...       ...       ...       ...
# 4995 -0.522879     SI2  1.793790  1.770852  0.628389  0.633468  0.424882
# 4996 -0.292430    VVS2  1.791691  1.748188  0.706718  0.710963  0.499687
# 4997  0.004321     SI1  1.782473  1.778151  0.804139  0.808211  0.588832
# 4998 -0.508638    VVS1  1.793092  1.748188  0.638489  0.641474  0.432969
# 4999 -0.481486     VS2  1.790988  1.740363  0.648360  0.651278  0.440909
#
#       cut_Fair  cut_Good  cut_Ideal  cut_Premium  cut_Very Good  color_D  \
# ...

# %%
rick_diamonds_clean = pd.read_csv('./dataset/rick_diamonds.csv')

# %%
rick_diamonds_clean['price_predicted'] = result['price_predicted']

# %%
rick_diamonds_clean.to_csv('./dataset/first_deliverable.csv')

# %%
rick_diamonds_clean.head(20)
# Out:
#     carat        cut color clarity  depth  table     x     y     z  \
# 0    0.91  Very Good     H     SI2   63.4   57.0  6.10  6.18  3.89
# 1    0.38       Good     F     VS2   60.3   61.0  4.68  4.71  2.83
# 2    0.52      Ideal     H     VS2   61.8   56.0  5.19  5.16  3.20
# 3    1.10      Ideal     G     VS1   61.3   56.0  6.65  6.69  4.09
# 4    2.28      Ideal     G     SI2   61.6   57.0  8.44  8.37  5.18
# 5    2.01  Very Good     J     VS2   60.8   58.0  8.08  8.16  4.94
# 6    1.06      Ideal     G     SI2   62.2   57.0  6.51  6.49  4.04
# 7    0.70    Premium     E     SI1   60.1   58.0  5.81  5.83  3.50
# 8    0.73    Premium     I     VS2   59.7   59.0  5.94  5.81  3.51
# 9    0.73      Ideal     H      IF   61.6   55.0  5.80  5.82  3.58
# 10   1.00       Good     D     VS2   64.1   58.0  6.24  6.33  4.03
# 11   0.33      Ideal     G    VVS2   60.1   57.0  4.48  4.51  2.70
# 12   0.54      Ideal     J    VVS2   61.6   57.0  5.25  5.23  3.23
# ...

# %%
rick_diamonds = pd.read_csv('./dataset/rick_diamonds.csv')

# %%
rick_diamonds_clean = pd.get_dummies(rick_diamonds)

# %%
rick_diamonds['price_predicted'] = model.predict(rick_diamonds_clean)

# %%
rick_diamonds.to_csv('./dataset/first_deliverable.csv')
