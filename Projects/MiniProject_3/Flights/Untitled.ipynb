# %%
import pandas as pd

# %%
data = pd.read_csv('./Table_12_1_Intl_Air_Pax_Traffic_Route_Analysis.csv')

# %%
data.head()
# Out:
#             rundate  this_period     foreign_region foreign_country  \
# 0  11/03/2020 11:02       202001            Unknown         Unknown
# 1  11/03/2020 11:02       202001            Unknown         Unknown
# 2  11/03/2020 11:02       202001  WESTERN EUROPE-EU         AUSTRIA
# 3  11/03/2020 11:02       202001  WESTERN EUROPE-EU         AUSTRIA
# 4  11/03/2020 11:02       202001  WESTERN EUROPE-EU         AUSTRIA
#
#                    UK_airport foreign_airport  total_pax_this_period  \
# 0  BELFAST CITY (GEORGE BEST)         Unknown                     30
# 1                  MANCHESTER         Unknown                    743
# 2                     GATWICK       INNSBRUCK                  32763
# 3                     GATWICK      KLAGENFURT                   1858
# 4                     GATWICK            LINZ                      0
#
#    total_pax_scheduled_this_period  total_pax_charter_this_period  \
# 0                               30                              0
# ...

# %%
mask = data['foreign_country'] == 'CHINA'
data.loc[mask, :]
# Out:
#                rundate  this_period foreign_region foreign_country  \
# 1421  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1422  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1423  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1424  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1425  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1426  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1427  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1428  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1429  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1430  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1431  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1432  11/03/2020 11:02       202001       FAR EAST           CHINA
# 1433  11/03/2020 11:02       202001       FAR EAST           CHINA
# ...

# %%
mask2 = data['foreign_airport'] == 'WUHAN TIANHE INTERNATIONAL'
data.loc[mask2, :]
# Out:
#                rundate  this_period foreign_region foreign_country UK_airport  \
# 1434  11/03/2020 11:02       202001       FAR EAST           CHINA   HEATHROW
#
#                  foreign_airport  total_pax_this_period  \
# 1434  WUHAN TIANHE INTERNATIONAL                   3999
#
#       total_pax_scheduled_this_period  total_pax_charter_this_period  \
# 1434                             3999                              0
#
#       total_pax_last_period  total_pax_scheduled_last_period  \
# 1434                   4510                             4510
#
#       total_pax_charter_last_period  total_pax_percent
# 1434                              0         -11.330377

# %%
data2 = pd.read_csv('./Table_14_International_and_Domestic_Freight.csv')

# %%
mask = data2['reporting_airport_group_name'] == 'London Area Airports'
data2.loc[mask, :]
# Out:
#                rundate  reporting_period reporting_airport_group_name  \
# 0  11/03/2020 10:21:21            202001         London Area Airports
# 1  11/03/2020 10:21:21            202001         London Area Airports
# 2  11/03/2020 10:21:21            202001         London Area Airports
# 3  11/03/2020 10:21:21            202001         London Area Airports
#
#   reporting_airport_name  freight_scheduled_passenger_aircraft_foreign_EU  \
# 0                GATWICK                                           64.510
# 1               HEATHROW                                         4465.783
# 2                  LUTON                                           20.966
# 3               STANSTED                                            0.000
#
#    freight_scheduled_cargo_aircraft_foreign_EU  \
# 0                                        0.000
# 1                                     1166.920
# 2                                     2764.223
# 3                                     5483.649
#
# ...

# %%
commodities = pd.read_csv('./CMO/2020-01.csv', sep = ',')

# %%
commodities
# Out:
#        20200106  11  11.1    202002     0    5307    5488    5302    5476  \
# 0      20200106  11    11  202004.0     0  5314.0  5501.0  5300.0  5480.0
# 1      20200106  11    11  202006.0     0  5311.0  5492.0  5300.0  5478.0
# 2      20200106  11    11  202008.0     0  5310.0  5482.0  5293.0  5472.0
# 3      20200106  11    11  202010.0     0  5302.0  5481.0  5292.0  5474.0
# 4      20200106  11    11  202012.0     0  5303.0  5483.0  5293.0  5473.0
# ...         ...  ..   ...       ...   ...     ...     ...     ...     ...
# 16256  20200131  22    11  202012.0  6350     NaN     NaN     NaN     NaN
# 16257  20200131  22    11  202012.0  6400     NaN     NaN     NaN     NaN
# 16258  20200131  22    11  202012.0  6450     NaN     NaN     NaN     NaN
# 16259  20200131  22    11  202012.0  6500     NaN     NaN     NaN     NaN
# 16260  20200131  22    11  202012.0  6550     NaN     NaN     NaN     NaN
#
#        5476.1      312   1676
# 0      5480.0   1875.0  13702
# ...

# %%
bovespa = pd.read_csv('./CMO/COTAHIST_A2020.TXT')

# %%
cmo = pd.read_csv('./CMO/cmo - Monthly Prices.csv')

# %%
cmo.head()
# Out:
#   Unnamed: 0 Crude oil, average Crude oil, Brent Crude oil, Dubai  \
# 0        NaN        CRUDE_PETRO      CRUDE_BRENT      CRUDE_DUBAI
# 1    1960M01               1,63               ..             1,63
# 2    1960M02               1,63               ..             1,63
# 3    1960M03               1,63               ..             1,63
# 4    1960M04               1,63               ..             1,63
#
#   Crude oil, WTI Coal, Australian Coal, South African Natural gas, US  \
# 0      CRUDE_WTI         COAL_AUS        COAL_SAFRICA         NGAS_US
# 1             ..               ..                  ..            0,14
# 2             ..               ..                  ..            0,14
# 3             ..               ..                  ..            0,14
# 4             ..               ..                  ..            0,14
#
#   Natural gas, Europe Liquefied natural gas, Japan  ... Coal, Colombian  \
# ...

# %%
cmo.columns
# Out:
# Index(['Unnamed: 0', 'Crude oil, average', 'Crude oil, Brent',
#        'Crude oil, Dubai', 'Crude oil, WTI', 'Coal, Australian',
#        'Coal, South African', 'Natural gas, US', 'Natural gas, Europe',
#        'Liquefied natural gas, Japan', 'Natural gas index', 'Cocoa',
#        'Coffee, Arabica', 'Coffee, Robusta', 'Tea, avg 3 auctions',
#        'Tea, Colombo', 'Tea, Kolkata', 'Tea, Mombasa', 'Coconut oil',
#        'Groundnuts', 'Fish meal', 'Groundnut oil', 'Palm oil',
#        'Palm kernel oil', 'Soybeans', 'Soybean oil', 'Soybean meal',
#        'Rapeseed oil', 'Sunflower oil', 'Barley', 'Maize', 'Sorghum',
#        'Rice, Thai 5% ', 'Rice, Thai 25% ', 'Rice, Thai A.1',
#        'Rice, Viet Namese 5%', 'Wheat, US SRW', 'Wheat, US HRW',
#        'Banana, Europe', 'Banana, US', 'Orange', 'Beef', 'Meat, chicken',
#        'Meat, sheep', 'Shrimps, Mexican', 'Sugar, EU', 'Sugar, US',
#        'Sugar, world', 'Tobacco, US import u.v.', 'Logs, Cameroon',
# ...

# %%
cmo.rename(columns = {'Unnamed: 0':'Date'}, inplace = True)

# %%
cmo.head()
# Out:
#       Date Crude oil, average Crude oil, Brent Crude oil, Dubai  \
# 0      NaN        CRUDE_PETRO      CRUDE_BRENT      CRUDE_DUBAI
# 1  1960M01               1,63               ..             1,63
# 2  1960M02               1,63               ..             1,63
# 3  1960M03               1,63               ..             1,63
# 4  1960M04               1,63               ..             1,63
#
#   Crude oil, WTI Coal, Australian Coal, South African Natural gas, US  \
# 0      CRUDE_WTI         COAL_AUS        COAL_SAFRICA         NGAS_US
# 1             ..               ..                  ..            0,14
# 2             ..               ..                  ..            0,14
# 3             ..               ..                  ..            0,14
# 4             ..               ..                  ..            0,14
#
#   Natural gas, Europe Liquefied natural gas, Japan  ... Coal, Colombian  \
# 0            NGAS_EUR                      NGAS_JP  ...        COAL_COL
# ...

# %%
cmo['Year'] = [str(item) for item in cmo['Date']]

# %%
cmo['Year'] = [item.split('M')[0] for item in cmo['Year']]

# %%
cmo
# Out:
#         Date Crude oil, average Crude oil, Brent Crude oil, Dubai  \
# 0        NaN        CRUDE_PETRO      CRUDE_BRENT      CRUDE_DUBAI
# 1    1960M01               1,63               ..             1,63
# 2    1960M02               1,63               ..             1,63
# 3    1960M03               1,63               ..             1,63
# 4    1960M04               1,63               ..             1,63
# ..       ...                ...              ...              ...
# 718  2019M10              57,27            59,37            58,47
# 719  2019M11              60,40            62,74            61,41
# 720  2019M12              63,35            65,85            64,41
# 721  2020M01              61,63            63,60            63,76
# 722  2020M02              53,35            55,00            54,51
#
#     Crude oil, WTI Coal, Australian Coal, South African Natural gas, US  \
# 0        CRUDE_WTI         COAL_AUS        COAL_SAFRICA         NGAS_US
# ...

# %%
mask = cmo['Year'] >= '2019'
cmo.loc[mask, :].groupby('Date')[['Crude oil, average', 'Crude oil, Brent', 'Crude oil, WTI']].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
c
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-a34b3ecf7c6d> in <module>
# ----> 1 cmo.datatype()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'datatype'

# %%
cmo.describe()
# Out:
#            Date Crude oil, average Crude oil, Brent Crude oil, Dubai  \
# count       722                723              723              723
# unique      722                507              445              481
# top     2020M01               1,63               ..             1,50
# freq          1                 12              228               12
#
#        Crude oil, WTI Coal, Australian Coal, South African Natural gas, US  \
# count             723              723                 723             723
# unique            424              306                 307             324
# top                ..               ..                  ..            0,16
# freq              264              120                 288              72
#
#        Natural gas, Europe Liquefied natural gas, Japan  ... Copra  \
# count                  723                          723  ...   723
# unique                 292                          280  ...   556
# ...
