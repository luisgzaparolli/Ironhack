# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Libraries
import math

# %% [markdown]
# # Challenge 1 - Handling Errors Using `if` Statements
#
# In many cases, we are able to identify issues that may come up in our code and handle those handlful of issues with an `if` statment. Sometimes we would like to handle different types of inputs and are aware that later in the code, we will have to write two different branches of code for the two different cases we allowed in the beginning.
#
# In the 3 cells below, add an `if` statment that will handle both types of input allowed in the functions.

# %%
# Modify the code below to handle positive and negative numbers by adding an if statement and performing a transformation:

def sqrt_for_all(x):
    """
    This function will take any real number and 
    return the square root of its magnitude.
    
    Input: Real number
    Output: Real number
    
    Sample Input: -4
    Sample Output: 2.0
    """
    if x <= 0:
        y = 0
    else:
        y = math.sqrt(x)
    return y

print(sqrt_for_all(2))
sqrt_for_all(-1)
# Out:
# 1.4142135623730951
# 0

# %%
# Modify the code below to handle zero as well. In the case of zero, return zero

def divide(x, y):
    """
    This function will take any two real numbers 
    and return their quotient. 
    If the denominator is zero, we return zero.
    
    Input: Real number
    Output: Real number
    
    Sample Input: 5, 1
    Sample Output: 5.0
    """
    if y == 0: #If inputed a zero number, raise the error.
        z = 0
    else:
        z = x / y
    return z
print(divide(10,2))
divide(5, 0)
# Out:
# 5.0
# 0

# %%
# Modify the function below that it will take either an number and a list or two numbers. 
# If we take two numbers, add them together and return a list of length 1. 
# Otherwise, add the number to every element of the list and return the resulting list

def add_elements(a: str, l):
    """
    This function takes either two numbers or a list and a number 
    and adds the number to all elements of the list.
    If the function only takes two numbers, it returns a list 
    of length one that is the sum of the numbers.
    
    Input: number and list or two numbers
    Output: list
    
    Sample Input: 5, 6
    Sample Output: [11]
    """
    if type(l) != list:
        z = list([a + l])
    else:
        z = [a + element for element in l]
    return z
        
print(add_elements(5, [6]))
add_elements(5, 6)
# Out:
# [11]
# [11]

# %% [markdown]
# # Challenge 2 - Fixing Errors to Get Code to Run
#
# Sometimes the error is not caused by the input but by the code itself. In the 2 following cells below, examine the error and correct the code to avoid the error.

# %%
# Modify the code below:

l = [1,2,3,4]

sum([element + 1 for element in l])
# Out:
# 14

# %%
# Modify the code below:

l = [1,2,3,4]

for element in l:
    print(f'The current element in the loop is {element}')
# Out:
# The current element in the loop is 1
# The current element in the loop is 2
# The current element in the loop is 3
# The current element in the loop is 4

# %% [markdown]
# # Challenge 3 - Handling Errors Using `try` and `except`
#
# The `try` and `except` clauses create a block for handling exceptions. When we wrap code in this block, we first attempt the code in the `try` and if an error is thrown, we can handle specific errors or all errors in the `except` portion.
#
# In the 4 cells below, modify the code to catch the error and print a meaningful message that will alert the user what went wrong. You may catch the error using a general `except` or a specific `except` for the error caused by the code.

# %%
# Modify the code below:
abc=[10,20,20]
try:
    print(abc[3])
except:
    raise IndexError("Number of elements in the argument its lower than the list.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-33d1d978713a> in <module>
#       3 try:
# ----> 4     print(abc[3])
#       5 except:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-33d1d978713a> in <module>
#       4     print(abc[3])
#       5 except:
# ----> 6     raise IndexError("Number of elements in the argument its lower than the list.")
#
# IndexError: Number of elements in the argument its lower than the list.

# %%
# Modify the code below:

x = 5
y = 0
try:
    z = x/y
except:
    raise ZeroDivisionError("The number entered needs to be different than zero.")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-34-c9eacbd41a51> in <module>
#       5 try:
# ----> 6     z = x/y
#       7 except:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-34-c9eacbd41a51> in <module>
#       6     z = x/y
#       7 except:
# ----> 8     raise ZeroDivisionError("The number entered needs to be different than zero.")
#
# ZeroDivisionError: The number entered needs to be different than zero.

# %%
for i in ['a','b','c']:
    try:
        print (i**2)
    except:
        raise TypeError("Math operation impossible with a string.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-689c329e549b> in <module>
#       2     try:
# ----> 3         print (i**2)
#       4     except:
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-689c329e549b> in <module>
#       3         print (i**2)
#       4     except:
# ----> 5         raise TypeError("Math operation impossible with a string.")
#
# TypeError: Math operation impossible with a string.

# %%
# Modify the code below:
try:
    print(some_string)
except:
    raise NameError("Element not defined.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-8b905ccb6ef4> in <module>
#       2 try:
# ----> 3     print(some_string)
#       4 except:
#
# NameError: name 'some_string' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-8b905ccb6ef4> in <module>
#       3     print(some_string)
#       4 except:
# ----> 5     raise NameError("Element not defined.")
#
# NameError: Element not defined.

# %% [markdown]
# # Bonus Challenge - Raise Errors on Your Own
#
# There are cases where you need to alert your users of a problem even if the input will not immediately produce an error. In these cases you may want to throw an error yourself to bring attention to the problem. In the 2 cells below, write the functions as directed and add the appropriate errors using the `raise` clause. Make sure to add a meaningful error message.

# %%
def log_square(x):
    """
    This function takes a numeric value and returns the 
    natural log of the square of the number.
    The function raises an error if the number is equal to zero.
    Use the math.log function in this funtion.
    
    Input: Real number
    Output: Real number or error
    
    Sample Input: 5
    Sample Output: 3.21887
    """
    if x <= 0:
        raise ValueError("Please input a positive number and different than zero.")
    else:
        z = math.log(x**2)
    return z
log_square(5)
    # Your code here:
# Out:
# 3.2188758248682006

# %%
import re
def check_capital(x):
    """
    This function returns true if the string contains 
    at least one capital letter and throws an error otherwise.
    
    Input: String
    Output: Bool or error message
    
    Sample Input: 'John'
    Sample Output: True
    """

    if type(x) != str:
        raise TypeError('Argument inputed isnt a string.')
    elif (bool(re.search('([A-Z])', x))) == True:
        print(True)
    else:
        raise TypeError('Not containing one capital letter.')
    return
    # Your code here:
a = [1,2,3]
print(check_capital(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-3dfe03da81b5> in <module>
#      21     # Your code here:
#      22 a = [1,2,3]
# ---> 23 print(check_capital(a))
#
# <ipython-input-130-3dfe03da81b5> in check_capital(x)
#      13
#      14     if type(x) != str:
# ---> 15         raise TypeError('Argument inputed isnt a string.')
#      16     elif (bool(re.search('([A-Z])', x))) == True:
#      17         print(True)
#
# TypeError: Argument inputed isnt a string.

# %%
b = 'aaaaaa'
print(check_capital(b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-c97c0eddcb9c> in <module>
#       1 b = 'aaaaaa'
# ----> 2 print(check_capital(b))
#
# <ipython-input-128-faedfe940d7c> in check_capital(x)
#      17         print(True)
#      18     else:
# ---> 19         raise TypeError('Not containing one capital letter.')
#      20     return
#      21     # Your code here:
#
# TypeError: Not containing one capital letter.
