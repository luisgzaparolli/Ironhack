# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-e41b3811197df7fbb60147e939917617.css" integrity="sha512-5Bs4ERl99/u2AUfpOZF2F0cdfNby7+Vd9teUshXUBPo5CjwECR7IAEf+weI/eCk5tF7K1h3O8hd8k0+P/HePeg==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
devs = [item.find_all('a')[1]['href'].strip().replace('/', '') for item in soup.find_all('article', attrs={'class':'Box-row d-flex'})]

# %%
devs
# Out:
# ['a8m',
#  'anitaa1990',
#  'streamich',
#  'hamelsmu',
#  'emmanuelle',
#  'arturbosch',
#  'jonahwilliams',
#  'jpuri',
#  'shimat',
#  'jackzampolin',
#  'kripken',
#  'JakeWharton',
#  'carllerche',
#  'isaacs',
#  'brocaar',
#  'UlisesGascon',
#  'diegomura',
#  'Palakis',
#  'mnapoli',
#  'ccorcos',
#  'rrousselGit',
#  'monperrus',
#  '4ian',
#  'nschloe',
#  'satya164']

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
repos = [item.find_all('a')[0]['href'].strip() for item in soup.find_all('h1', attrs={'class':'h3 lh-condensed'})]

# %%
repos
# Out:
# ['/pennsignals/chime',
#  '/matrix-org/synapse',
#  '/huawei-noah/AdderNet',
#  '/lazyprogrammer/machine_learning_examples',
#  '/VertaAI/modeldb',
#  '/stanfordnlp/stanza',
#  '/geerlingguy/ansible-for-devops',
#  '/dmlc/gluon-cv',
#  '/ansible/ansible',
#  '/ExpDev07/coronavirus-tracker-api',
#  '/gto76/python-cheatsheet',
#  '/ycm-core/YouCompleteMe',
#  '/localstack/localstack',
#  '/vishnubob/wait-for-it',
#  '/OpenMined/PySyft',
#  '/lark-parser/lark',
#  '/vinta/awesome-python',
#  '/huggingface/transformers',
#  '/python-telegram-bot/python-telegram-bot',
#  '/tensorflow/tfx',
#  '/bitcoin/bips',
#  '/fishtown-analytics/dbt',
#  '/django/django',
#  '/python/mypy',
#  '/pypa/pip']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
img = ['http:' + item.find_all('img')[0]['src'].strip() for item in soup.find_all('a', attrs={'class':'image'})]

# %%
img
# Out:
# ['http://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  'http://upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
python = ['https://en.wiktionary.org/' + urls['href'] for urls in item[0].find_all('a') for item in soup.find_all('div', attrs={'class':'mw-parser-output'})]

# %%
python
# Out:
# ['https://en.wiktionary.org/https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/https://en.wiktionary.org/wiki/python',
#  'https://en.wiktionary.org/#Snakes',
#  'https://en.wiktionary.org/#Ancient_Greece',
#  'https://en.wiktionary.org/#Media_and_entertainment',
#  'https://en.wiktionary.org/#Computing',
#  'https://en.wiktionary.org/#Engineering',
#  'https://en.wiktionary.org/#Roller_coasters',
#  'https://en.wiktionary.org/#Vehicles',
#  'https://en.wiktionary.org/#Weaponry',
#  'https://en.wiktionary.org/#People',
#  'https://en.wiktionary.org/#Other_uses',
#  'https://en.wiktionary.org/#See_also',
#  'https://en.wiktionary.org//w/index.php?title=Python&action=edit&section=1',
#  'https://en.wiktionary.org//wiki/Pythonidae',
#  'https://en.wiktionary.org//wiki/Python_(genus)',
#  'https://en.wiktionary.org//w/index.php?title=Python&action=edit&section=2',
#  'https://en.wiktionary.org//wiki/Python_(mythology)',
# ...

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
uschanged = []
for item in soup.find_all('div', attrs={'class':'uscitem'}):
    for titles in item.find_all('div', attrs={'class': 'usctitlechanged'}):
        for rawtitle in titles:
            try:
                rawtitle = rawtitle.strip()
                uschanged.append(rawtitle)
            except:
                pass
for item in range(len(uschanged)):
    uschanged.remove('')
uschanged
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-690b2822cc42> in <module>
#      13                 pass
#      14 for item in range(len(uschanged)):
# ---> 15     uschanged.remove('')
#      16 uschanged
#
# ValueError: list.remove(x): x not in list

# %%
uschanged
# Out:
# ['Title 1 - General Provisions',
#  'Title 2 - The Congress',
#  'Title 5 - Government Organization and Employees',
#  'Title 6 - Domestic Security',
#  'Title 7 - Agriculture',
#  'Title 8 - Aliens and Nationality',
#  'Title 12 - Banks and Banking',
#  'Title 15 - Commerce and Trade',
#  'Title 16 - Conservation',
#  'Title 17 - Copyrights',
#  'Title 18 - Crimes and Criminal Procedure',
#  'Title 20 - Education',
#  'Title 21 - Food and Drugs',
#  'Title 22 - Foreign Relations and Intercourse',
#  'Title 23 - Highways',
#  'Title 26 - Internal Revenue Code',
#  'Title 29 - Labor',
#  'Title 30 - Mineral Lands and Mining',
#  'Title 31 - Money and Finance',
#  'Title 36 - Patriotic and National Observances, Ceremonies, and Organizations',
#  "Title 38 - Veterans' Benefits",
#  'Title 41 - Public Contracts',
#  'Title 42 - The Public Health and Welfare',
#  'Title 43 - Public Lands',
#  'Title 44 - Public Printing and Documents',
#  'Title 45 - Railroads',
# ...

# %%
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
tit = soup.find_all('div', attrs={'class':'usctitlechanged'})
[item.text.strip() for item in tit]
# Out:
# ['Title 1 - General Provisions ٭',
#  'Title 2 - The Congress',
#  'Title 5 - Government Organization and Employees ٭',
#  'Title 6 - Domestic Security',
#  'Title 7 - Agriculture',
#  'Title 8 - Aliens and Nationality',
#  'Title 12 - Banks and Banking',
#  'Title 15 - Commerce and Trade',
#  'Title 16 - Conservation',
#  'Title 17 - Copyrights ٭',
#  'Title 18 - Crimes and Criminal Procedure ٭',
#  'Title 20 - Education',
#  'Title 21 - Food and Drugs',
#  'Title 22 - Foreign Relations and Intercourse',
#  'Title 23 - Highways ٭',
#  'Title 26 - Internal Revenue Code',
#  'Title 29 - Labor',
#  'Title 30 - Mineral Lands and Mining',
#  'Title 31 - Money and Finance ٭',
#  'Title 36 - Patriotic and National Observances, Ceremonies, and Organizations ٭',
#  "Title 38 - Veterans' Benefits ٭",
#  'Title 41 - Public Contracts ٭',
#  'Title 42 - The Public Health and Welfare',
#  'Title 43 - Public Lands',
#  'Title 44 - Public Printing and Documents ٭',
#  'Title 45 - Railroads',
# ...

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
topten = [item.find_all('a')[0].text for item in soup.find_all('h3', attrs={'class':'title'})]

# %%
topten
# Out:
# ['RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'YASER ABDEL SAID',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
table = soup.find_all("tbody", attrs={'id':'tbody'})[0]
dates_times = table.find_all('td', attrs={'class': 'tabev6'})
date_time = [item.find('a').text.split() for item in dates_time]
date = [item[0] for item in date_time]
time = [item[1] for item in date_time]
directions = table.find_all('td', attrs={'class': 'tabev1'})
direction = [float(item.text.replace('\xa0','')) for item in directions]
direction = np.reshape(direction,(50,2))
lat = [item[0] for item in direction]
long = [item[1] for item in direction]
regions = table.find_all('td', attrs={'class': 'tb_region'})
region = [item.text.replace('\xa0','') for item in regions]
data = np.transpose([date,time,lat,long,region])
df = pd.DataFrame(data, columns=['date', 'time', 'latitude', 'longitude','region_name'])
df = df.iloc[:20,:]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-667ab636b166> in <module>
#       4 table = soup.find_all("tbody", attrs={'id':'tbody'})[0]
#       5 dates_times = table.find_all('td', attrs={'class': 'tabev6'})
# ----> 6 date_time = [item.find('a').text.split() for item in dates_time]
#       7 date = [item[0] for item in date_time]
#       8 time = [item[1] for item in date_time]
#
# NameError: name 'dates_time' is not defined

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here
def count_tweets():
    user = input('Enter a twitter name: ')
    url = 'https://twitter.com/'
    url = url + user
    response = requests.get(url)
    if response.status_code == 200:
        html = response.content
        soup = BeautifulSoup(html)
        followers_nav = soup.find('li', {'class':'ProfileNav-item ProfileNav-item--tweets is-active'})
        follower = int(followers_nav.find('a').find('span', {'class':'ProfileNav-value'})['data-count'])
        print(f'{user} have {follower} followers.')
    else:
        print('Account name not found!')

# %%
count_tweets()
# Out:
# Enter a twitter name: jairbolsonaro
# jairbolsonaro have 8846 followers.

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here
def count_followers():
    user = input('Enter a twitter name: ')
    url = 'https://twitter.com/'
    url = url + user
    response = requests.get(url)
    if response.status_code == 200:
        html = response.content
        soup = BeautifulSoup(html)
        followers_nav = soup.find('li', {'class':'ProfileNav-item ProfileNav-item--followers'})
        follower = int(followers_nav.find('a').find('span', {'class':'ProfileNav-value'})['data-count'])
        print(f'{user} have {follower} followers.')
    else:
        print('Account name not found!')

# %%
count_followers()
# Out:
# Enter a twitter name: jairbolsonaro
# jairbolsonaro have 6185516 followers.

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
table = soup.find_all('div', attrs = {'class': 'central-featured-lang'})
language = [item.find('strong').text for item in table]
number = [item.find('bdi').text.replace('\xa0','') for item in table]
list_wiki = list(zip(language, number))

# %%
list_wiki
# Out:
# [('English', '6029000+'),
#  ('Español', '1581000+'),
#  ('日本語', '1193000+'),
#  ('Deutsch', '2406000+'),
#  ('Русский', '1602000+'),
#  ('Français', '2187000+'),
#  ('Italiano', '1588000+'),
#  ('中文', '1101000+'),
#  ('Português', '1023000+'),
#  ('Polski', '1388000+')]

# %%
language = []
topten = [item.find_all('a')[0].text for item in soup.find_all('h3', attrs={'class':'title'})]

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
table = soup.find_all('div', attrs = {'class': 'column-one-third'})
kind_list = [kind.text for subquery in table for kind in subquery.find_all('a')]

# %%
kind_list
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport']

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
table = soup.find_all('table', attrs = {'class': 'wikitable'})[0]
headers = [header.text.strip().replace('\n','') for header in table.find_all('th')]
data = [data.text.strip() for data in table.find_all('td')]
nrows = int(len(data)/ncols)
ncols = int(len(headers))
df = pd.DataFrame(np.array(data).reshape((nrows, ncols)), columns=headers)
df.loc[:9, :]
# Out:
#   Rank                            Language Speakers(millions)  \
# 0    1                    Mandarin Chinese                918
# 1    2                             Spanish                480
# 2    3                             English                379
# 3    4  Hindi (Sanskritised Hindustani)[9]                341
# 4    5                             Bengali                228
# 5    6                          Portuguese                221
# 6    7                             Russian                154
# 7    8                            Japanese                128
# 8    9                 Western Punjabi[10]               92.7
# 9   10                             Marathi               83.1
#
#   % of the World population(March 2019)[8]      Language familyBranch
# 0                                   11.922        Sino-TibetanSinitic
# 1                                    5.994       Indo-EuropeanRomance
# 2                                    4.922      Indo-EuropeanGermanic
# ...

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here
user = str(input('Twitter username: '))
qty_tweets = int(input('How many tweets do you want to see? '))
response = requests.get(url + user)
html = response.content
soup = BeautifulSoup(html)
tweets = soup.find_all('p', attrs={'class':'TweetTextSize'})
for i in range(qty_tweets):
    tweet = tweets[i].text.replace('\xa0', '')
    print(tweet)
    print('\n')
# Out:
# Twitter username: jairbolsonaro
# How many tweets do you want to see? 25
# - Petrobras reduz preço dos combustíveis:
#
# - Nesta data a Petrobras reduziu, nas refinarias, o preço da gasolina em 7,5%, do óleo diesel em 12% e do gás em 5%.
#
# - Com isso, no acumulado do ano, a redução do diesel é de 29,1%, da gasolina 30,1% e do gás 7,9%.
#
#
# 4- ESTRADAS / CAMINHONEIROS: Monitoramento, orientação e indicação de postos de triagem e equipamentos, assistência a profissionais autônomos em grupos de risco. Encaminhamento de proposta de prorrogação de prazos de renovações a vencer, incluindo carteira de motorista (CNH).
#
#
# 2- Portos: Proteção máxima para continuidade de operações: equipamentos ao campo, afastamento de grupo de risco, escala digital, restrições a tripulações de fora.
#
# 3- AVIAÇÃO: MP garante minimamente o setor e mantém linhas essenciais no abastecimento de remédios e insumos.pic.twitter.com/WhyuEXKMdV
#
#
# ...

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
table = soup.find_all('table', attrs = {'class': 'chart'})[0]
headers = ['movie_name', 'initial_release', 'director_name', 'stars']
title = [title.find('a').text for title in table.find_all('td', attrs = {'class': 'titleColumn'})]
initial_release = [release.text.strip().replace('(','').replace(')','') for release in table.find_all('span', attrs = {'class': 'secondaryInfo'})]
directoractor_list = [director.find('a')['title'].split(',') for director in table.find_all('td', attrs = {'class': 'titleColumn'})]
director_name = [item[0].replace(' (dir.)', '') for item in directoractor_list]
stars_list = [stars.find('strong').text for stars in table.find_all('td', attrs = {'class': 'ratingColumn imdbRating'})]
data = list(zip(title, initial_release, director_name, stars_list))
df = pd.DataFrame(np.array(data), columns=headers)

# %%
df
# Out:
#                                       movie_name initial_release  \
# 0                          Um Sonho de Liberdade            1994
# 1                              O Poderoso Chefão            1972
# 2                           O Poderoso Chefão II            1974
# 3                 Batman: O Cavaleiro das Trevas            2008
# 4                       12 Homens e uma Sentença            1957
# ..                                           ...             ...
# 245                               Um Contratempo            2016
# 246                         Guardiões da Galáxia            2014
# 247                                  A Chantagem            2015
# 248                             Feitiço do Tempo            1993
# 249  Neon Genesis Evangelion: O Fim do Evangelho            1997
#
#             director_name stars
# 0          Frank Darabont   9.2
# 1    Francis Ford Coppola   9.1
# 2    Francis Ford Coppola   9.0
# 3       Christopher Nolan   9.0
# ...

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
table = soup.find_all('table', attrs = {'class': 'chart'})[0]

title = [title.find('a').text for title in table.find_all('td', attrs = {'class': 'titleColumn'})]

initial_release = [release.text.strip().replace('(','').replace(')','') for release in table.find_all('span', attrs = {'class': 'secondaryInfo'})]

title_url = ['http://imdb.com' + url.find('a')['href'] for url in table.find_all('td', attrs = {'class': 'titleColumn'})]
title_url = title_url[:10]

summary = []
for urls in title_url:
    html = requests.get(urls).content
    soup = BeautifulSoup(html)
    summary.append(soup.find_all('div', attrs = {'class': 'summary_text'})[0].text.strip())

headers = ['movie_name', 'initial_release', 'summary']
data = list(zip(title, initial_release, summary))
df = pd.DataFrame(np.array(data), columns=headers)
df
# Out:
#                                 movie_name initial_release  \
# 0                    Um Sonho de Liberdade            1994
# 1                        O Poderoso Chefão            1972
# 2                     O Poderoso Chefão II            1974
# 3           Batman: O Cavaleiro das Trevas            2008
# 4                 12 Homens e uma Sentença            1957
# 5                     A Lista de Schindler            1993
# 6     O Senhor dos Anéis: O Retorno do Rei            2003
# 7         Pulp Fiction: Tempo de Violência            1994
# 8                  Três Homens em Conflito            1966
# 9  O Senhor dos Anéis: A Sociedade do Anel            2001
#
#                                              summary
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker wreaks havo...
# ...

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'
# Out:
# Enter the city: Divinópolis

# %%
# your code here
response = requests.get(url)
results = response.json()
temperature = results['main']['temp']
wind_speed = results['wind']['speed']
description = results['weather'][0]['description']
weather = results['weather'][0]['main']
print(f'Temperature = {temperature}, Wind Speed = {wind_speed}, Description = {description} and Weather = {weather}')
# Out:
# Temperature = 23.66, Wind Speed = 1.43, Description = light rain and Weather = Rain

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
websites = []
for i in range(1, 51, 1):
    page = 'page-'+ str(i) + '.html'
    website = 'http://books.toscrape.com/catalogue/' + page
    websites.append(website)

# %%
# your code here
df = pd.DataFrame()

for url in websites:
    html = requests.get(url).content
    soup = BeautifulSoup(html)
    table = soup.find_all('li', attrs = {'class' : 'col-xs-6'})
    
    book_name = [name.find_all('a')[0].find('img')['alt'] for name in table]
    price = [price.text for price in soup.find_all('p', attrs = {'class': 'price_color'})]
    stock = [stock.text.strip() for stock in soup.find_all('p', attrs = {'class' : 'instock availability'})]
    
    mini_df = pd.DataFrame({'book_name' : book_name,
                           'price' : price,
                           'stock' : stock})
    df = pd.concat([df, mini_df])
    df = df.reset_index(drop=True)

# %%
df
# Out:
#                                              book_name   price     stock
# 0                                 A Light in the Attic  £51.77  In stock
# 1                                   Tipping the Velvet  £53.74  In stock
# 2                                           Soumission  £50.10  In stock
# 3                                        Sharp Objects  £47.82  In stock
# 4                Sapiens: A Brief History of Humankind  £54.23  In stock
# ..                                                 ...     ...       ...
# 995  Alice in Wonderland (Alice's Adventures in Won...  £55.53  In stock
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  £57.06  In stock
# 997  A Spy's Devotion (The Regency Spies of London #1)  £16.97  In stock
# 998                1st to Die (Women's Murder Club #1)  £53.98  In stock
# 999                 1,000 Places to See Before You Die  £26.08  In stock
#
# [1000 rows x 3 columns]
